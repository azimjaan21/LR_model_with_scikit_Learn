# %% [markdown]
# <a href="https://colab.research.google.com/github/azimjaan21/LR_model_with_scikit_Learn/blob/main/regression_of_home_price_(practice).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_LR.csv', index_col=0)
df.head()
# Out:
#         district  rooms  size  level  max_levels    price
# 0   Юнусабадский      3  57.0      4           4  52000.0
# 1  Яккасарайский      2  52.0      4           5  56000.0
# 2   Чиланзарский      2  42.0      4           4  37000.0
# 3   Чиланзарский      3  65.0      1           4  49500.0
# 4   Чиланзарский      3  70.0      3           5  55000.0

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.10, random_state=42)

# %% [markdown]
# Simple Linear Regression using **Scikit-Learn**

# %%
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()

# From dataset to NP Array
x_train = np.asanyarray(train_set[['size']])
y_train = np.asanyarray(train_set[['price']])

# Training the model
LR_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# theta1 and theta0
print('theta1: ', LR_model.coef_[0][0])
print('theta0: ', LR_model.intercept_[0])
# Out:
# theta1:  802.3232902993149
# theta0:  -2229.317702946668

# %%
# Line
plt.figure(figsize=(10,6))
sns.scatterplot(x='size', y='price', data=df)
plt.plot(x_train, LR_model.coef_[0][0]*train_set['size'] + LR_model.intercept_[0], color='red') # y = a + b*x
plt.xlabel('Size')
plt.ylabel('Price')
plt.title('Simple Linear Regression')
plt.show()

# %% [markdown]
# **Model**

# %%
x_test = np.asanyarray(test_set[['size']])
y_test = np.asanyarray(test_set[['price']])

# %%
y_predict = LR_model.predict(x_test)

# %% [markdown]
# Mean Absolute Error **(MAE)** & Root Mean Square Error **(RMSE)**
#
#
#
# ---
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

MAE = mean_absolute_error(y_test, y_predict)
RMSE = np.sqrt(mean_squared_error(y_test, y_predict))

print('MAE:', MAE)
print('RMSE:', RMSE)
# Out:
# MAE: 12316.997447293636
# RMSE: 18029.62991620007
